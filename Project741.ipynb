# %%
# import modules
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize #special package in pandas
import json
import re
import csv
import sys
import nltk

# %% [markdown]
# ## <font color = "red"> Converting from JSON to CSV </font>
#
# Since the data was huge, it would take every fucntion that we ran on the dataframe hours to run. So, through research we found that converting a json file to csv would optimize the running time.

# %%
df = pd.read_csv("Project/PhonesData.csv",index_col=[0])
df.head()
# Out:
#          asin helpful  overall  \
# 0  120401325X  [0, 0]        4
# 1  120401325X  [0, 0]        5
# 2  120401325X  [0, 0]        5
# 3  120401325X  [4, 4]        4
# 4  120401325X  [2, 3]        5
#
#                                           reviewText   reviewTime  \
# 0  They look good and stick good! I just don't li...  05 21, 2014
# 1  These stickers work like the review says they ...  01 14, 2014
# 2  These are awesome and make my phone look so st...  06 26, 2014
# 3  Item arrived in great time and was in perfect ...  10 21, 2013
# 4  awesome! stays on, and looks great. can be use...   02 3, 2013
#
#        reviewerID      reviewerName  \
# 0  A30TL5EWN6DFXT         christina
# 1   ASY55RVNIL0UD          emily l.
# 2  A2TMXE2AFO7ONB             Erica
# 3   AWJ0WZQYMYFQ4                JM
# 4   ATX7CZYFXI1KW  patrice m rogoza
#
#                                      summary  unixReviewTime
# 0                                 Looks Good      1400630400
# ...

# %%
#Checking number of observations
df.shape[0]
# Out:
# 194439

# %% [markdown]
# ## <font color = "red" >Data Cleaning & Preparation </font>

# %% [markdown]
# ### 1. Removing NA values

# %%
#Removing observations with NA values
df=df.dropna(axis=0, how='any')

# %% [markdown]
# ### 2. The helpful attribute was a string, for future operations we had to first convert it into list

# %%
#Slicing the brackets from helpful colummn
df['helpful'] = df.helpful.str.slice(1,-1)
df.head()
# Out:
#          asin helpful  overall  \
# 0  120401325X    0, 0        4
# 1  120401325X    0, 0        5
# 2  120401325X    0, 0        5
# 3  120401325X    4, 4        4
# 4  120401325X    2, 3        5
#
#                                           reviewText   reviewTime  \
# 0  They look good and stick good! I just don't li...  05 21, 2014
# 1  These stickers work like the review says they ...  01 14, 2014
# 2  These are awesome and make my phone look so st...  06 26, 2014
# 3  Item arrived in great time and was in perfect ...  10 21, 2013
# 4  awesome! stays on, and looks great. can be use...   02 3, 2013
#
#        reviewerID      reviewerName  \
# 0  A30TL5EWN6DFXT         christina
# 1   ASY55RVNIL0UD          emily l.
# 2  A2TMXE2AFO7ONB             Erica
# 3   AWJ0WZQYMYFQ4                JM
# 4   ATX7CZYFXI1KW  patrice m rogoza
#
#                                      summary  unixReviewTime
# 0                                 Looks Good      1400630400
# ...

# %%
#Splitting the values based on ,
df['new'] = df['helpful'].str.split(',')
df.head()
# Out:
#          asin helpful  overall  \
# 0  120401325X    0, 0        4
# 1  120401325X    0, 0        5
# 2  120401325X    0, 0        5
# 3  120401325X    4, 4        4
# 4  120401325X    2, 3        5
#
#                                           reviewText   reviewTime  \
# 0  They look good and stick good! I just don't li...  05 21, 2014
# 1  These stickers work like the review says they ...  01 14, 2014
# 2  These are awesome and make my phone look so st...  06 26, 2014
# 3  Item arrived in great time and was in perfect ...  10 21, 2013
# 4  awesome! stays on, and looks great. can be use...   02 3, 2013
#
#        reviewerID      reviewerName  \
# 0  A30TL5EWN6DFXT         christina
# 1   ASY55RVNIL0UD          emily l.
# 2  A2TMXE2AFO7ONB             Erica
# 3   AWJ0WZQYMYFQ4                JM
# 4   ATX7CZYFXI1KW  patrice m rogoza
#
#                                      summary  unixReviewTime      new
# 0                                 Looks Good      1400630400  [0,  0]
# ...

# %%
df.shape[0]
# Out:
# 190814

# %%
#Creating a copy of dataframe
df2 = df
df.head()
# Out:
#          asin helpful  overall  \
# 0  120401325X    0, 0        4
# 1  120401325X    0, 0        5
# 2  120401325X    0, 0        5
# 3  120401325X    4, 4        4
# 4  120401325X    2, 3        5
#
#                                           reviewText   reviewTime  \
# 0  They look good and stick good! I just don't li...  05 21, 2014
# 1  These stickers work like the review says they ...  01 14, 2014
# 2  These are awesome and make my phone look so st...  06 26, 2014
# 3  Item arrived in great time and was in perfect ...  10 21, 2013
# 4  awesome! stays on, and looks great. can be use...   02 3, 2013
#
#        reviewerID      reviewerName  \
# 0  A30TL5EWN6DFXT         christina
# 1   ASY55RVNIL0UD          emily l.
# 2  A2TMXE2AFO7ONB             Erica
# 3   AWJ0WZQYMYFQ4                JM
# 4   ATX7CZYFXI1KW  patrice m rogoza
#
#                                      summary  unixReviewTime      new
# 0                                 Looks Good      1400630400  [0,  0]
# ...

# %% [markdown]
# ### Computing upvotes and downvotes
#
# new_0 = upvotes <br>
# new_1 = donwvotes

# %%
# expand df.tags into its own dataframe
new = df['new'].apply(pd.Series)

# rename each variable is tags
new = new.rename(columns = lambda x : 'new_' + str(x))

# view the tags dataframe
new
# Out:
#        new_0 new_1
# 0          0     0
# 1          0     0
# 2          0     0
# 3          4     4
# 4          2     3
# 5          1     2
# 6          0     0
# 7          1     2
# 8          2     3
# 9          1     1
# 10         0     0
# 11         2     3
# 12         3     3
# 13        12    16
# 14         1     1
# 15         0     0
# 16         2     3
# 17         0     0
# 18         2     3
# 19         0     0
# 20         0     0
# 21         0     0
# 22         0     0
# 23         0     0
# 24         0     0
# 25         0     0
# 26         0     0
# 27         3     4
# 28         0     0
# 29         0     0
# ...      ...   ...
# 194409     0     0
# 194410     0     0
# 194411     0     0
# 194412     0     0
# 194413     0     0
# 194414     0     0
# 194415     0     0
# 194416     0     0
# 194417     0     0
# 194418     0     0
# 194419     0     0
# 194420     0     0
# 194421     0     0
# 194422     0     0
# 194423     0     0
# ...

# %%
new['new_0'] = pd.to_numeric(new['new_0'])
new['new_1'] = pd.to_numeric(new['new_1'])
type(new['new_0'][0])
# Out:
# numpy.int64

# %%
# join the tags dataframe back to the original dataframe
df = pd.concat([df[:], new[:]], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190814 entries, 0 to 194438
# Data columns (total 12 columns):
# asin              190814 non-null object
# helpful           190814 non-null object
# overall           190814 non-null int64
# reviewText        190814 non-null object
# reviewTime        190814 non-null object
# reviewerID        190814 non-null object
# reviewerName      190814 non-null object
# summary           190814 non-null object
# unixReviewTime    190814 non-null int64
# new               190814 non-null object
# new_0             190814 non-null int64
# new_1             190814 non-null int64
# dtypes: int64(4), object(8)
# memory usage: 18.9+ MB

# %% [markdown]
# ### Further data preparation
#
# The 'helpful' attribute consisted of entries that had values like [0,0]. Meaning, there were no upvotes or downvotes. These entries weren't useful for our study. Thus, we decided to removie such entires.
# The code below keeps entries in a new dataframe where the sum of upvotes and downvotes are greater than 5 i.e <br>
# upvotes + downvotes > 5 <br>

# %%
df2 = df[df['new_0'] + df['new_1'] > 5]
df2['helpful_percent']=df2['new_0']*100/(df2['new_0']+df2['new_1'])
df2['helpful_percent']=df2['helpful_percent'].astype(int)
# Out:
# /Users/shrutihegde/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/shrutihegde/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df2.head()
# Out:
#           asin helpful  overall  \
# 3   120401325X    4, 4        4
# 12  3998899561    3, 3        5
# 13  3998899561  12, 16        5
# 27  6073894996    3, 4        4
# 54  7532385086    3, 3        5
#
#                                            reviewText   reviewTime  \
# 3   Item arrived in great time and was in perfect ...  10 21, 2013
# 12  Performs exactly as advertised . It's very  st...   12 5, 2013
# 13  Unlike Most of the Rechargeable Battery cases,...  09 27, 2013
# 27  This is a nice charger but you can tell it was...  03 20, 2013
# 54  I love this case! It's so pretty.And I love th...   02 2, 2011
#
#         reviewerID   reviewerName  \
# 3    AWJ0WZQYMYFQ4             JM
# 12   A6Q0P54QSP11J  Olivia ysiak
# 13   ANMATY0L0HX6Y   Sasha Malkin
# 27  A29OXVQRZ154KX     Don Powell
# 54  A2G38P52ZF5TTH         Allana
#
#                                               summary  unixReviewTime  \
# 3                                               Cute!      1382313600
# ...

# %%
df2.shape[0]
# Out:
# 14973

# %% [markdown]
# ### Computing other semantic features

# %%
#Number of words in reviews
df2['review_word_count'] = df2['reviewText'].apply(lambda x: len(str(x).split(" ")))
df2[['reviewText','review_word_count']].head()
# Out:
# /Users/shrutihegde/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                            reviewText  review_word_count
# 3   Item arrived in great time and was in perfect ...                 51
# 12  Performs exactly as advertised . It's very  st...                 48
# 13  Unlike Most of the Rechargeable Battery cases,...                240
# 27  This is a nice charger but you can tell it was...                 85
# 54  I love this case! It's so pretty.And I love th...                 23

# %%
df2#Number of words in summary
df2['summary_word_count'] = df2['summary'].apply(lambda x: len(str(x).split(" ")))
df2[['summary','summary_word_count']].head()
# Out:
# /Users/shrutihegde/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                               summary  summary_word_count
# 3                                               Cute!                   1
# 12                        Absolutely love the case !!                   5
# 13  Best Rechargeable Battery Case on the Market!!...                   8
# 27                         Solid Charger but RF noisy                   5
# 54                                        I recommend                   2

# %%
#Number of sentences
df2['sentences_count']=df2['reviewText'].str.count('.')
df2[['reviewText','sentences_count']].head()
# Out:
# /Users/shrutihegde/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                            reviewText  sentences_count
# 3   Item arrived in great time and was in perfect ...              275
# 12  Performs exactly as advertised . It's very  st...              257
# 13  Unlike Most of the Rechargeable Battery cases,...             1255
# 27  This is a nice charger but you can tell it was...              400
# 54  I love this case! It's so pretty.And I love th...              114

# %%
#Number of characters
df2['char_count'] = df2['reviewText'].str.len() ## this also includes spaces
df2[['reviewText','char_count']].head()
# Out:
# /Users/shrutihegde/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                            reviewText  char_count
# 3   Item arrived in great time and was in perfect ...         275
# 12  Performs exactly as advertised . It's very  st...         257
# 13  Unlike Most of the Rechargeable Battery cases,...        1255
# 27  This is a nice charger but you can tell it was...         400
# 54  I love this case! It's so pretty.And I love th...         114

# %%
#Computing reviewer expertise
df_rcount = df2.groupby(['reviewerID']).size().reset_index(name='reviewer_count')
df_rcount.head()

df_final= pd.merge(df2, df_rcount, on="reviewerID")
df_final.head()
# Out:
#          asin helpful  overall  \
# 0  120401325X    4, 4        4
# 1  3998899561    3, 3        5
# 2  3998899561  12, 16        5
# 3  6073894996    3, 4        4
# 4  7532385086    3, 3        5
#
#                                           reviewText   reviewTime  \
# 0  Item arrived in great time and was in perfect ...  10 21, 2013
# 1  Performs exactly as advertised . It's very  st...   12 5, 2013
# 2  Unlike Most of the Rechargeable Battery cases,...  09 27, 2013
# 3  This is a nice charger but you can tell it was...  03 20, 2013
# 4  I love this case! It's so pretty.And I love th...   02 2, 2011
#
#        reviewerID   reviewerName  \
# 0   AWJ0WZQYMYFQ4             JM
# 1   A6Q0P54QSP11J  Olivia ysiak
# 2   ANMATY0L0HX6Y   Sasha Malkin
# 3  A29OXVQRZ154KX     Don Powell
# 4  A2G38P52ZF5TTH         Allana
#
#                                              summary  unixReviewTime  \
# 0                                              Cute!      1382313600
# ...

# %% [markdown]
# ### Sentiment Analysis Using LIWC

# %%
#importing relevant libraries
import liwc
from collections import Counter

# %%
# read in liwc dictionary and define liwc parser
parse, category_names = liwc.load_token_parser('LIWC2007_English080730.dic')

df2 = pd.DataFrame()

df_final=df_final[~df_final['reviewText'].isnull()]
#creating unique primary key based on index
df_final.reset_index(inplace=True)
df_final
# Out:
#        index        asin   helpful  overall  \
# 0          0  120401325X      4, 4        4
# 1          1  3998899561      3, 3        5
# 2          2  3998899561    12, 16        5
# 3          3  6073894996      3, 4        4
# 4          4  7532385086      3, 3        5
# 5          5  8288853439      4, 4        5
# 6          6  B00C96CMEK      3, 5        5
# 7          7  9658231942      3, 3        5
# 8          8  9658231950    11, 11        1
# 9          9  9658231950      1, 5        5
# 10        10  9861203192    25, 25        5
# 11        11  B0089F49P0      3, 3        5
# 12        12  9981724580    20, 24        3
# 13        13  B0009SHMUY    43, 43        5
# 14        14  B000UNNV5S    43, 43        5
# 15        15  B001BR95PW    16, 16        4
# 16        16  B001GJ0E4G    23, 24        4
# 17        17  B001TK3AC0  107, 112        4
# 18        18  B001UC9NOQ  178, 179        5
# 19        19  B001UCIIU6    17, 18        4
# ...

# %%
# tokenize and pass to liwc
#cp = 0
for index,row in df_final.iterrows(): # loop over rows of data frame
    text = row['reviewText']
    #print(row['asin']) # print name you gave to each text
    #print(row['reviewText'])
    textwords = nltk.tokenize.word_tokenize(text) # tokenize
    
    # get word count
    wc = len(textwords)
    #print("Word count: ",wc)
    
    # now flatmap over all the categories in all of the tokens using a generator:
    text_counts = Counter(category for token in textwords for category in parse(token))
    # for each relevant category print the percentage    
    df1 = pd.DataFrame.from_dict(text_counts, orient='index')
    df1 = df1.T
    df1['rid'] = row['reviewerID']
    df1['pid'] = row['asin']
    df1['helpfulness'] = row['helpful_percent']
    df2 = df2.append(df1)

df2=df2.reset_index(drop=True)
#print(cp)
# Out:
# /Users/shrutihegde/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
df2.shape
# Out:
# (14918, 67)

# %%
df2['rid']

# %%
df3=df2

# %%
X = df2.drop(['helpfulness','rid','pid'],axis=1)

Y = df2['helpfulness']

# %%
from sklearn.feature_selection import f_classif
from sklearn import preprocessing
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
linear_dep = pd.DataFrame()
for col in X.columns:
    linear_dep.loc[col, 'pearson_corr'] = X[col].corr(Y)
linear_dep['abs_pearson_corr'] = abs(linear_dep['pearson_corr'])
for col in X.columns:
    mask = X[col].notnull()
    (linear_dep.loc[col, 'F'], linear_dep.loc[col, 'p_value']) = f_classif(pd.DataFrame(X.loc[mask, col]), Y.loc[mask])
linear_dep.sort_values('abs_pearson_corr', ascending=False, inplace=True)
linear_dep.drop('abs_pearson_corr', axis=1, inplace=True)
linear_dep.reset_index(inplace=True)
linear_dep.rename(columns={'index':'variable'}, inplace=True)


linear_dep.sort_values(by=['pearson_corr'])
# Out:
#    variable  pearson_corr          F        p_value
# 59    swear     -0.013708   1.922924   9.941904e-05
# 63       we     -0.000252   1.582459   5.501409e-03
# 62   filler      0.001943   0.895080   6.830717e-01
# 61    death      0.003887   1.914235   1.111783e-04
# 60    anger      0.003948   4.987045   5.558759e-28
# 58      sad      0.015259   6.414193   1.240129e-40
# 57    shehe      0.018930   1.480092   1.550713e-02
# 56     they      0.020489   8.494157   7.962452e-60
# 55   friend      0.021503   2.236554   1.346582e-06
# 54   humans      0.021883   6.362280   3.655465e-40
# 53    relig      0.025319   2.852347   8.977052e-11
# 52   negemo      0.025891  11.813794   2.286614e-91
# 51   ingest      0.031032   3.659819   6.417460e-17
# 50    money      0.032418  13.712258  1.200553e-109
# 49   family      0.037395   2.335274   3.161898e-07
# 48   negate      0.038236  13.821300  1.062956e-110
# 47   assent      0.042421   4.556690   2.676299e-24
# ...

# %%
linear_dep.sort_values(by=['pearson_corr'], ascending=False)
# Out:
#    variable  pearson_corr          F        p_value
# 0    posemo      0.102015  18.930599  3.531464e-160
# 1      feel      0.096794  10.921084   8.110996e-83
# 2     space      0.093416  20.312237  1.454991e-173
# 3   article      0.092202  21.342200  1.559445e-183
# 4      incl      0.090717  20.537367  9.614407e-176
# 5   percept      0.086712  14.747326  1.191584e-119
# 6      conj      0.085616  20.016681  1.059885e-170
# 7     inhib      0.085487  10.026225   2.736772e-74
# 8    affect      0.084857  18.301373  4.429783e-154
# 9   relativ      0.084736  20.591688  2.864068e-176
# 10    quant      0.083957  18.984392  1.063287e-160
# 11    preps      0.083181  21.234427  1.720978e-182
# 12    funct      0.082342  21.073751  6.175548e-181
# 13  cogmech      0.080350  20.214946  1.273623e-172
# 14  present      0.079127  18.992837  8.806748e-161
# 15      bio      0.078614  11.480658   3.581259e-88
# 16   tentat      0.076878  17.716537  2.066086e-148
# ...

# %%
df_final.shape

# %%
import statsmodels.api as sm

# %%
X=X.fillna(0)
Y=Y.fillna(0)

# %%
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)

# %%
model.summary()

# %%
type(result)
# Out:
# statsmodels.iolib.summary.Summary

# %%
results_as_html = result.tables[1].as_html()
result1 = pd.read_html(results_as_html, header=0, index_col=0)[0].sort_values(by= ['P>|t|'])

# %%
result1.to_csv("results.csv")

# %% [markdown]
# ## <font color ="red"> Data Pre-processing </font>
#
# - Stopword removal & Unwanted characters removal
# - Tokenizing
# - Lemmatizing

# %%
# remove unwanted characters, numbers and symbols
df_final['reviewText'] = df_final['reviewText'].str.replace("[^a-zA-Z#]", " ")

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
# function to remove stopwords
def remove_stopwords(rev):
    rev_new = " ".join([i for i in rev if i not in stop_words])
    return rev_new

# remove short words (length < 3)
df_final['reviewText'] = df_final['reviewText'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

# remove stopwords from the text
reviews = [remove_stopwords(r.split()) for r in df_final['reviewText']]

# make entire text lowercase
reviews = [r.lower() for r in reviews]

# %%
import spacy

nlp = spacy.load('en', disable=['parser', 'ner'])

def lemmatization(texts, tags=['NOUN', 'ADJ']): # filter noun and adjective
       output = []
       for sent in texts:
             doc = nlp(" ".join(sent)) 
             output.extend([token.lemma_ for token in doc if token.pos_ in tags])
       return output

# %%
#tokenize the reviews and then lemmatize the tokenized reviews

tokenized_reviews = pd.Series(reviews).apply(lambda x: x.split())
print(tokenized_reviews[1])

# %%
#print lemmatized review
reviews_2 = lemmatization(tokenized_reviews)
print(reviews_2[1])

# %%
#common word removal
freq = pd.Series(' '.join(df_final['reviewText']).split()).value_counts()[:10]
freq

freq = list(freq.index)
df_final['reviewText'] = df_final['reviewText'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
df_final['reviewText'].head()

# %%
#Rare word removal
freq = pd.Series(' '.join(df_final['reviewText']).split()).value_counts()[:10]
freq
freq = list(freq.index)
df_final['reviewText'] = df_final['reviewText'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
df_final['reviewText'].head()

# %%
df.to_csv(r'C:\Users\Kalpita Raut\Documents\MIM\Spring 2019\741\Project brainstorm\PhonesData_final.csv',encoding='utf-8')

# %% [markdown]
# ## <font color="red"> Visualizing top 50 words </font>

# %%
#Print top 50 words
import nltk
from nltk.tokenize import word_tokenize
frequency_dist = nltk.FreqDist(reviews_2)
sorted(frequency_dist,key=frequency_dist.__getitem__, reverse=True)[0:50]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud = WordCloud(background_color='white').generate_from_frequencies(frequency_dist)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Building the predictive model

# %%
import statsmodels.api as sm # import statsmodels 

# X usually means our input variables (or independent variables)
X = df_final[["summary_word_count","overall","review_word_count","char_count","reviewer_count","sentences_count"]]

## Y usually means our output/dependent variable
y = df_final['helpful_percent']
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Print out the statistics
model.summary()

# %% [markdown]
# ## Interpretation of the model

# %% [markdown]
# The equation obtained from the model is as follows :
#
# <font color="blue"> **helpful_percent = <i>8.1281*overall + <i>1.4342*summary_word_count + <i>0.1084*reviewer_count + <br> <i>0.0575*review_word_count - <i>0.0050(char_count +sentences count)** </font>
#
# In simple or multiple linear regression, the size of the coefficient for each independent variable gives you the size of the effect that variable is having on your dependent variable, and the sign on the coefficient (positive or negative) gives you the direction of the effect.
#
# According to our model's equation, the three most significant variables are :
# 1. **Overall** : overall rating of the product
# 2. **Summrary_word_count** : Total number of words in the summary (after removing stopwords and stemming)
# 3. **Reviewer_count** : Reviewer expertise
#
# <i> Since the p-values are really small(< 0.001) for all the independent variables, they are all significant to our model. </i>
#
# In multiple regression analysis the "Adjusted R squared" gives an idea of how the model generalises. Both Rsquare and the adjusted Rsquare give you an idea of how many data points fall within the line of the regression equation. However, there is one main difference between Rsquare and the adjusted Rsquare: Rsqaure assumes that every single variable explains the variation in the dependent variable. The adjusted Rsquare tells you the percentage of variation explained by only the independent variables that actually affect the dependent variable.
#
# According to our results, the **adjusted rsqaure value = 0.918**. Which is good since it explains 91.8% variability.

# %% [markdown]
# ## Conclusion on the basis of the model

# %% [markdown]
# Thus, our model explains that certain features in the review text do contribute towards how helpful a review is. These features are :
# - Overall rating of the product
# - Total number of words in the summary of the review
# - How expert the reviewer is.
